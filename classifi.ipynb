# %% [markdown]
# <a href="https://colab.research.google.com/github/blanpa/test/blob/main/classifi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret-nightly[full] --quiet

# %%
from pycaret.datasets import get_data

# %%
df = get_data("bank")
# Out:
#    age           job  marital  education  ... pdays  previous poutcome deposit
# 0   58    management  married   tertiary  ...    -1         0  unknown      no
# 1   44    technician   single  secondary  ...    -1         0  unknown      no
# 2   33  entrepreneur  married  secondary  ...    -1         0  unknown      no
# 3   47   blue-collar  married    unknown  ...    -1         0  unknown      no
# 4   33       unknown   single    unknown  ...    -1         0  unknown      no
#
# [5 rows x 17 columns]

# %%
import pycaret.classification as pyc

# %%
setup = pyc.setup(data = df, target = "deposit", silent = True, use_gpu = True)
# Out:
#                                Description             Value
# 0                               session_id              7690
# 1                                   Target           deposit
# 2                              Target Type            Binary
# 3                            Label Encoded     no: 0, yes: 1
# 4                            Original Data       (45211, 17)
# 5                           Missing Values             False
# 6                         Numeric Features                 7
# 7                     Categorical Features                 9
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set       (31647, 48)
# 12                    Transformed Test Set       (13564, 48)
# 13                      Shuffle Train-Test              True
# ...

# %%
best = pyc.compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# catboost              CatBoost Classifier    0.9110  0.9373  0.4967  0.6541
# lightgbm  Light Gradient Boosting Machine    0.9101  0.9363  0.4989  0.6469
# xgboost         Extreme Gradient Boosting    0.9072  0.9317  0.4867  0.6306
# gbc          Gradient Boosting Classifier    0.9068  0.9257  0.4119  0.6584
# rf               Random Forest Classifier    0.9053  0.9275  0.3787  0.6626
# lr                    Logistic Regression    0.9026  0.9022  0.3479  0.6513
# lda          Linear Discriminant Analysis    0.9023  0.9068  0.4434  0.6096
# ada                  Ada Boost Classifier    0.9015  0.9117  0.3819  0.6246
# ridge                    Ridge Classifier    0.9002  0.0000  0.2826  0.6668
# et                 Extra Trees Classifier    0.8983  0.9093  0.3284  0.6185
# knn                K Neighbors Classifier    0.8836  0.7663  0.2775  0.4980
# ...

# %%
best
